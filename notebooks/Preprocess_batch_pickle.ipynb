# %%
import sys
sys.path.append(r"C://Users/ech77/OneDrive - University of Cambridge/PhD work/Code/hBN_PL/src")
import hbn_pl.batch_preprocess_pickle as bppp
from pathlib import Path

DATA_DIR = Path("C://Users/ech77/OneDrive - University of Cambridge/PhD work/Data/Data Jan 2026/Sample 7 PL master folder zero B field/Capped/Region1.pickle")

WAIT_FOR_CONFIRM = True   # pause between files so user can inspect plots

bppp.batch_process_pickle(DATA_DIR, WAIT_FOR_CONFIRM)
# Out:
# Processing: Emitter 16
# Performing background subtraction...
# Successfully subtracted background.
# Detecting cosmic ray frames...
# Detected 0 cosmic ray frames: []
# Cosmic ray wavelengths: {}
# Cosmic ray detection complete.
# Removing cosmic rays from 0 frames: []
# Running simple bad frame detection...
# Detected bad frames due to intensity drop 0.6: [ 0 12 13 14 17 18 20 26 31 35 38]
# Removing 11 frames: [ 0 12 13 14 17 18 20 26 31 35 38]
# Successfully removed bad frames.
# Averaging and normalising frames into a single spectrum...
# Successfully averaged and normalised frames.
# Estimated ZPL: 636.360834040494
# Progress: |██████████████████████████████| 100% (16/16 emitters)
#
# Options:
# ENTER → Save
# s     → Skip
# g     → Mark good emitter + save
# b     → Go back to previous emitter
# q     → Quit batch
# Saved: C:\Users\ech77\OneDrive - University of Cambridge\PhD work\Data\Data Jan 2026\Sample 7 PL master folder zero B field\Capped\Emitter_16_cleaned.npz
# ...
