# %%
import hbn_pl.batch_preprocess_pickle as bppp

DATA_DIR = Path("C://Users/ech77/OneDrive - University of Cambridge/Data Jan 2026/Automated PL study on Sample 7/Region 2/Region2.pickle")

WAIT_FOR_CONFIRM = True   # pause between files so user can inspect plots

bppp.batch_process_pickle(DATA_DIR, WAIT_FOR_CONFIRM)
# Out:
# Processing: Emitter 2
# Performing background subtraction...
# Successfully subtracted background.
# Detecting cosmic ray frames...
# Detected 2 cosmic ray frames: [3, 22]
# Cosmic ray wavelengths: {3: [766.9122632098417, 766.5629756756078], 22: [652.7966983943062]}
# Cosmic ray detection complete.
# Removing cosmic rays from 2 frames: [3, 22]
# Running simple bad frame detection...
# Detected bad frames due to intensity drop 0.6: [12 27 28 31 33]
# Removing 5 frames: [12 27 28 31 33]
# Successfully removed bad frames.
# Averaging and normalising frames into a single spectrum...
# Successfully averaged and normalised frames.
# Estimated ZPL: 623.9456393338098
# Progress: |█-----------------------------| 5% (2/40 emitters)
#
# Options:
# ENTER → Save
# s     → Skip
# g     → Mark good emitter + save
# b     → Go back to previous emitter
# q     → Quit batch
# User aborted batch processing.
#
# Batch processing complete.
