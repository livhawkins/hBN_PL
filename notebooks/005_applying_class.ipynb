# %%
from peak_finder import PeakFinder
from zpl_classifier import ZPLClassification

# %%
finder = PeakFinder(x, y)
finder.find_peaks(prominence=0.1)

peaks = finder.extract_peak_parameters()

classifier = ZPLClassification(peaks)
result = classifier.classify()

print(result)
