# %%
print("hello world")

# %%
import hbn_pl.batch_peaks as bpeaks

DATA_DIR = Path("C://Users/ech77/OneDrive - University of Cambridge/Data Jan 2026/Large PL study, 0T")

#Set fit initial fit parameters for the peaks of interest here. You can edit these during the batch process if needed.
targets = [11, 39, 150, 172]
window = 4
sigma = 2

bpeaks.batch_peak_fitting(DATA_DIR)
# Out:
# Processing: 2026 January 23 11_06_07 Sample7_capped_500uW_grating150_exposure20_emitter 10_cleaned.npz
# ZPL: 619.2010869214863
# Interactive figure saved to C:\Users\ech77\OneDrive - University of Cambridge\Data Jan 2026\Large PL study, 0T\2026 January 23 11_06_07 Sample7_capped_500uW_grating150_exposure20_emitter 10_cleaned_interactive.html
# Current Fit Parameters
# ----------------------
# targets = [11, 39, 150, 172]
# window  = 4
# sigma   = 2
#
# Progress |██----------------------------| 8% (10/117) files
#
# Commands
# ENTER = save
# s = skip file
# p = choose peaks
# e = edit parameters
# r = refit
# b = back
# q = quit
#
# Batch finished.
