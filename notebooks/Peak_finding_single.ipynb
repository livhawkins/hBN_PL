# %%
from pathlib import Path
import numpy as np
import hbn_pl.plot as plot
import hbn_pl.peaks as peaks

# %%
DATA_DIR = Path("C://Users/ech77/OneDrive - University of Cambridge/Data Jan 2026/Automated PL study on Sample 7/Region 2")
FILE_NAME = 'Emitter_38_cleaned.npz'

spe_path = DATA_DIR / FILE_NAME
data = np.load(spe_path)
energy = data["energy"]
intensity = data["intensity"]
zpl_wavelength = data["zpl_wavelength"]
#plot.plot_spectrum(energy, intensity)

# %%
targets = [9, 39, 150, 172]
window = 3
sigma = 0.5

fit_results = []
print("ZPL:", zpl_wavelength)

for t in targets:
    res = peaks.fit_peak_gaussian(energy, intensity, center_guess=t, window=window, sigma_guess=sigma)
    print(f"Fitted center for target {t} meV: {res['center']:.2f} ± {res['center_err']:.2f} meV")
    fit_results.append(res)

spe_path = Path(spe_path)
base_name = spe_path.stem  # strip directory & extension
html_filename = spe_path.parent / f"{base_name}_interactive.html"
plot.plot_psb_plotly(energy, intensity, fit_results, targets, window=window, filename=html_filename) #Save interactive HTML
# Out:
# ZPL: 622.7215712921319
# Fitted center for target 9 meV: 9.72 ± 0.08 meV
# Fitted center for target 39 meV: 38.81 ± 0.07 meV
# Fitted center for target 150 meV: 149.14 ± 0.04 meV
# Fitted center for target 172 meV: 171.03 ± 0.06 meV
# Interactive figure saved to C:\Users\ech77\OneDrive - University of Cambridge\Data Jan 2026\Automated PL study on Sample 7\Region 2\Emitter_38_cleaned_interactive.html
